# %%
# !pip install easyocr
# !pip install imutils
# !pip install matplotlib
# Out:
# Requirement already satisfied: easyocr in c:\users\s.santhosh\miniconda3\envs\env_easyocr\lib\site-packages (1.4.1)
# Requirement already satisfied: torchvision>=0.5 in c:\users\s.santhosh\miniconda3\envs\env_easyocr\lib\site-packages (from easyocr) (0.12.0)
# Requirement already satisfied: Pillow<8.3.0 in c:\users\s.santhosh\miniconda3\envs\env_easyocr\lib\site-packages (from easyocr) (8.2.0)
# Requirement already satisfied: numpy in c:\users\s.santhosh\miniconda3\envs\env_easyocr\lib\site-packages (from easyocr) (1.21.5)
# Requirement already satisfied: torch in c:\users\s.santhosh\miniconda3\envs\env_easyocr\lib\site-packages (from easyocr) (1.11.0)
# Requirement already satisfied: PyYAML in c:\users\s.santhosh\miniconda3\envs\env_easyocr\lib\site-packages (from easyocr) (6.0)
# Requirement already satisfied: scikit-image in c:\users\s.santhosh\miniconda3\envs\env_easyocr\lib\site-packages (from easyocr) (0.19.2)
# Requirement already satisfied: scipy in c:\users\s.santhosh\miniconda3\envs\env_easyocr\lib\site-packages (from easyocr) (1.8.0)
# Requirement already satisfied: python-bidi in c:\users\s.santhosh\miniconda3\envs\env_easyocr\lib\site-packages (from easyocr) (0.4.2)
# Requirement already satisfied: opencv-python-headless in c:\users\s.santhosh\miniconda3\envs\env_easyocr\lib\site-packages (from easyocr) (4.5.5.64)
# Requirement already satisfied: typing_extensions in c:\users\s.santhosh\miniconda3\envs\env_easyocr\lib\site-packages (from torchvision>=0.5->easyocr) (3.10.0.2)
# Requirement already satisfied: requests in c:\users\s.santhosh\miniconda3\envs\env_easyocr\lib\site-packages (from torchvision>=0.5->easyocr) (2.27.1)
# Requirement already satisfied: six in c:\users\s.santhosh\miniconda3\envs\env_easyocr\lib\site-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\s.santhosh\miniconda3\envs\env_easyocr\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\s.santhosh\miniconda3\envs\env_easyocr\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\s.santhosh\miniconda3\envs\env_easyocr\lib\site-packages (from requests->torchvision>=0.5->easyocr) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\s.santhosh\miniconda3\envs\env_easyocr\lib\site-packages (from requests->torchvision>=0.5->easyocr) (3.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\s.santhosh\miniconda3\envs\env_easyocr\lib\site-packages (from scikit-image->easyocr) (1.3.0)
# Requirement already satisfied: networkx>=2.2 in c:\users\s.santhosh\miniconda3\envs\env_easyocr\lib\site-packages (from scikit-image->easyocr) (2.7.1)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\s.santhosh\miniconda3\envs\env_easyocr\lib\site-packages (from scikit-image->easyocr) (2.9.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\s.santhosh\miniconda3\envs\env_easyocr\lib\site-packages (from scikit-image->easyocr) (21.3)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\s.santhosh\miniconda3\envs\env_easyocr\lib\site-packages (from scikit-image->easyocr) (2022.3.16)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\s.santhosh\miniconda3\envs\env_easyocr\lib\site-packages (from packaging>=20.0->scikit-image->easyocr) (3.0.7)
# Collecting imutils
#   Downloading imutils-0.5.4.tar.gz (17 kB)
# Building wheels for collected packages: imutils
#   Building wheel for imutils (setup.py): started
#   Building wheel for imutils (setup.py): finished with status 'done'
#   Created wheel for imutils: filename=imutils-0.5.4-py3-none-any.whl size=25858 sha256=9a05abc70df02f4f90db1a641bd8c7c6d2c2a83568c8fb95b67c0ba855f2bf16
#   Stored in directory: c:\users\s.santhosh\appdata\local\pip\cache\wheels\4b\a5\2d\4a070a801d3a3d93f033d3ee9728f470f514826e89952df3ea
# Successfully built imutils
# Installing collected packages: imutils
# Successfully installed imutils-0.5.4
# Collecting matplotlib
#   Downloading matplotlib-3.5.1-cp39-cp39-win_amd64.whl (7.2 MB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.31.1-py3-none-any.whl (899 kB)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\s.santhosh\miniconda3\envs\env_easyocr\lib\site-packages (from matplotlib) (8.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\s.santhosh\miniconda3\envs\env_easyocr\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\s.santhosh\miniconda3\envs\env_easyocr\lib\site-packages (from matplotlib) (3.0.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\s.santhosh\miniconda3\envs\env_easyocr\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\s.santhosh\miniconda3\envs\env_easyocr\lib\site-packages (from matplotlib) (1.21.5)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.0-cp39-cp39-win_amd64.whl (51 kB)
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\s.santhosh\miniconda3\envs\env_easyocr\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: kiwisolver, fonttools, cycler, matplotlib
# Successfully installed cycler-0.11.0 fonttools-4.31.1 kiwisolver-1.4.0 matplotlib-3.5.1

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
import imutils
import easyocr

# %%
img = cv2.imread('image3.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(gray, cv2.COLOR_BGR2RGB))

# %%
bfilter = cv2.bilateralFilter(gray, 11, 17, 17) #Noise reduction
edged = cv2.Canny(bfilter, 30, 200) #Edge detection
plt.imshow(cv2.cvtColor(edged, cv2.COLOR_BGR2RGB))

# %%
keypoints = cv2.findContours(edged.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
contours = imutils.grab_contours(keypoints)
contours = sorted(contours, key=cv2.contourArea, reverse=True)[:10]

# %%
location = None
for contour in contours:
    approx = cv2.approxPolyDP(contour, 10, True)
    if len(approx) == 4:
        location = approx
        break

# %%
location
# Out:
# array([[[263, 334]],
#
#        [[264, 363]],
#
#        [[369, 362]],
#
#        [[366, 333]]], dtype=int32)

# %%
(x,y) = np.where(mask==255)
(x1, y1) = (np.min(x), np.min(y))
(x2, y2) = (np.max(x), np.max(y))
cropped_image = gray[x1:x2+1, y1:y2+1]

# %%
plt.imshow(cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB))

# %%
reader = easyocr.Reader(['en'])
result = reader.readtext(cropped_image)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [23], in <cell line: 2>()
#       1 reader = easyocr.Reader(['en'])
# ----> 2 result = reader.readtext(cropped_image)
#
# File ~\miniconda3\envs\env_easyocr\lib\site-packages\easyocr\easyocr.py:385, in Reader.readtext(self, image, decoder, beamWidth, batch_size, workers, allowlist, blocklist, detail, rotation_info, paragraph, min_size, contrast_ths, adjust_contrast, filter_ths, text_threshold, low_text, link_threshold, canvas_size, mag_ratio, slope_ths, ycenter_ths, height_ths, width_ths, y_ths, x_ths, add_margin, output_format)
#     379 '''
#     380 Parameters:
#     381 image: file path or numpy-array or a byte stream object
#     382 '''
#     383 img, img_cv_grey = reformat_input(image)
# --> 385 horizontal_list, free_list = self.detect(img, min_size, text_threshold,\
#     386                                          low_text, link_threshold,\
#     387                                          canvas_size, mag_ratio,\
#     388                                          slope_ths, ycenter_ths,\
#     389                                          height_ths,width_ths,\
#     390                                          add_margin, False)
#     391 # get the 1st result from hor & free list as self.detect returns a list of depth 3
#     392 horizontal_list, free_list = horizontal_list[0], free_list[0]
#
# File ~\miniconda3\envs\env_easyocr\lib\site-packages\easyocr\easyocr.py:275, in Reader.detect(self, img, min_size, text_threshold, low_text, link_threshold, canvas_size, mag_ratio, slope_ths, ycenter_ths, height_ths, width_ths, add_margin, reformat, optimal_num_chars)
#     272 if reformat:
#     273     img, img_cv_grey = reformat_input(img)
# --> 275 text_box_list = get_textbox(self.detector, img, canvas_size, mag_ratio,
#     276                             text_threshold, link_threshold, low_text,
#     277                             False, self.device, optimal_num_chars)
#     279 horizontal_list_agg, free_list_agg = [], []
#     280 for text_box in text_box_list:
#
# File ~\miniconda3\envs\env_easyocr\lib\site-packages\easyocr\detection.py:95, in get_textbox(detector, image, canvas_size, mag_ratio, text_threshold, link_threshold, low_text, poly, device, optimal_num_chars)
#      93 result = []
#      94 estimate_num_chars = optimal_num_chars is not None
# ---> 95 bboxes_list, polys_list = test_net(canvas_size, mag_ratio, detector,
#      96                                    image, text_threshold,
#      97                                    link_threshold, low_text, poly,
#      98                                    device, estimate_num_chars)
#      99 if estimate_num_chars:
#     100     polys_list = [[p for p, _ in sorted(polys, key=lambda x: abs(optimal_num_chars - x[1]))]
#     101                   for polys in polys_list]
#
# File ~\miniconda3\envs\env_easyocr\lib\site-packages\easyocr\detection.py:55, in test_net(canvas_size, mag_ratio, net, image, text_threshold, link_threshold, low_text, poly, device, estimate_num_chars)
#      52 score_link = out[:, :, 1].cpu().data.numpy()
#      54 # Post-processing
# ---> 55 boxes, polys, mapper = getDetBoxes(
#      56     score_text, score_link, text_threshold, link_threshold, low_text, poly, estimate_num_chars)
#      58 # coordinate adjustment
#      59 boxes = adjustResultCoordinates(boxes, ratio_w, ratio_h)
#
# File ~\miniconda3\envs\env_easyocr\lib\site-packages\easyocr\craft_utils.py:236, in getDetBoxes(textmap, linkmap, text_threshold, link_threshold, low_text, poly, estimate_num_chars)
#     234 if poly and estimate_num_chars:
#     235     raise Exception("Estimating the number of characters not currently supported with poly.")
# --> 236 boxes, labels, mapper = getDetBoxes_core(textmap, linkmap, text_threshold, link_threshold, low_text, estimate_num_chars)
#     238 if poly:
#     239     polys = getPoly_core(boxes, labels, mapper, linkmap)
#
# File ~\miniconda3\envs\env_easyocr\lib\site-packages\easyocr\craft_utils.py:31, in getDetBoxes_core(textmap, linkmap, text_threshold, link_threshold, low_text, estimate_num_chars)
#      28 ret, link_score = cv2.threshold(linkmap, link_threshold, 1, 0)
#      30 text_score_comb = np.clip(text_score + link_score, 0, 1)
# ---> 31 nLabels, labels, stats, centroids = cv2.connectedComponentsWithStats(text_score_comb.astype(np.uint8), connectivity=4)
#      33 det = []
#      34 mapper = []
#
# error: Unknown C++ exception from OpenCV code

# %%
result
# Out:
# [([[6, 4], [128, 4], [128, 34], [6, 34]], 'HR.26 BR.9044', 0.5823533145684263)]

# %%
text = result[0][-2]
font = cv2.FONT_HERSHEY_SIMPLEX
res = cv2.putText(img, text=text, org=(approx[0][0][0], approx[1][0][1]+60), fontFace=font, fontScale=1, color=(0,255,0), thickness=2, lineType=cv2.LINE_AA)
res = cv2.rectangle(img, tuple(approx[0][0]), tuple(approx[2][0]), (0,255,0),3)
plt.imshow(cv2.cvtColor(res, cv2.COLOR_BGR2RGB))
